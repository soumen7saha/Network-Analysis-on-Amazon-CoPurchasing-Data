# %% [markdown]
# ## Importing the required modules

# %%
import string
import re
from nltk.corpus import stopwords
from stemming.porter2 import stem
import networkx 
from operator import itemgetter

# %% [markdown]
# ## Accessing the meta-data

# %%
Metadata_File = open('amazon-meta.txt', 'r', encoding = 'utf-8', errors = 'ignore')
Amazon_Products = {}

# %%
(Id, ASIN, Title, Categories, Group, Copurchased, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff) = \
    ("", "", "", "", "", "", 0, 0, 0.0, 0, 0.0)

for line in Metadata_File:
   
    line = line.strip()

    if(line.startswith("Id")):
        Id = line[3:].strip()

    elif(line.startswith("ASIN")):
        ASIN = line[5:].strip()

    elif(line.startswith("title")):
        Title = line[6:].strip()
        Title = ' '.join(Title.split())

    elif(line.startswith("group")):
        Group = line[6:].strip()

    elif(line.startswith("salesrank")):
        SalesRank = line[10:].strip()

    elif(line. startswith("similar")):
        ls = line.split()
        Copurchased = ' '.join([c for c in ls[2:]])

    elif(line.startswith("categories")):
        ls = line.split()
        Categories = ' '.join((Metadata_File.readline()).lower() for i in range(int(ls[1].strip())))
        Categories = re.compile('[%s]' % re.escape(string.digits + string.punctuation)).sub(' ', Categories)
        Categories = ' '.join(set(Categories.split()) - set(stopwords.words("english")))
        Categories = ' '.join(stem(word) for word in Categories.split())

    elif(line.startswith("reviews")):
        ls = line.split()
        TotalReviews = ls[2].strip()
        AvgRating = ls[7].strip()

    elif(line == ""):
        try:
            MetaData = {}
            if (ASIN != ""):
                Amazon_Products[ASIN] = MetaData   
            MetaData['Id'] = Id
            MetaData['Title'] = Title
            MetaData['Categories'] = ' '.join(set(Categories.split()))
            MetaData['Group'] = Group
            MetaData['Copurchased'] = Copurchased
            MetaData['SalesRank'] = int(SalesRank)
            MetaData['TotalReviews'] = int(TotalReviews)
            MetaData['AvgRating'] = float(AvgRating)
            MetaData['DegreeCentrality'] = DegreeCentrality
            MetaData['ClusteringCoeff'] = ClusteringCoeff
        except NameError:
            continue
    (Id, ASIN, Title, Categories, Group, Copurchased, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff) = \
        ("", "", "", "", "", "", 0, 0, 0.0, 0, 0.0)

Metadata_File.close()

# %% [markdown]
# ## Filtering out data related to book records

# %%
Amazon_Books = {}
for asin, metadata in Amazon_Products.items():
    if (metadata['Group'] == 'Book'):
        Amazon_Books[asin] = Amazon_Products[asin]

# %%
for asin, metadata in Amazon_Books.items():
    Amazon_Books[asin]['Copurchased'] = ' '.join([cp for cp in metadata['Copurchased'].split() if cp in Amazon_Books.keys()])

# %%
Amazon_Books
# Out:
# {'0827229534': {'Id': '1',
#   'Title': 'Patterns of Preaching: A Sermon Sampler',
#   'Categories': 'spiritu religion subject sermon christian book preach clergi',
#   'Group': 'Book',
#   'Copurchased': '0804215715 156101074X 0687023955 0687074231 082721619X',
#   'SalesRank': 396585,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0738700797': {'Id': '2',
#   'Title': 'Candlemas: Feast of Flames',
#   'Categories': 'spiritu religion subject base book witchcraft wicca earth',
#   'Group': 'Book',
#   'Copurchased': '0738700827 1567184960 1567182836 0738700525 0738700940',
#   'SalesRank': 168596,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486287785': {'Id': '3',
#   'Title': 'World War II Allied Fighter Planes Trading Cards',
#   'Categories': 'hobbi garden subject craft book general home',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1270652,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0842328327': {'Id': '4',
#   'Title': 'Life Application Bible Commentary: 1 and 2 Timothy and Titus',
#   'Categories': 'live guid spiritu text religion translat sacr commentari applic subject christian book new studi life histori general refer bibl testament discipleship',
#   'Group': 'Book',
#   'Copurchased': '0842328130 0842330313 0842328610 0842328572',
#   'SalesRank': 631289,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1577943082': {'Id': '5',
#   'Title': 'Prayers That Avail Much for Business: Executive',
#   'Categories': 'live spiritu worship religion subject christian devot book prayerbook busi',
#   'Group': 'Book',
#   'Copurchased': '157794349X 0892749504 1577941829 0892749563',
#   'SalesRank': 455160,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486220125': {'Id': '6',
#   'Title': 'How the Other Half Lives: Studies Among the Tenements of New York',
#   'Categories': 'categori essay nonfict scienc jewish urban state camera subject book social art america histori photographi general photo unit sociolog',
#   'Group': 'Book',
#   'Copurchased': '0486401960 0452283612 0486229076 0714840343',
#   'SalesRank': 188784,
#   'TotalReviews': 17,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0231118597': {'Id': '8',
#   'Title': 'Losing Matt Shepard',
#   'Categories': 'criminolog lesbian u subject crimin crime book general gay polit nonfict',
#   'Group': 'Book',
#   'Copurchased': '0375727191 080148605X 1560232579 0300089023',
#   'SalesRank': 277409,
#   'TotalReviews': 15,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1859677800': {'Id': '9',
#   'Title': 'Making Bread: The Taste of Traditional Home-Baking',
#   'Categories': 'bread cook subject wine book food bake',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 949166,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375709363': {'Id': '10',
#   'Title': 'The Edward Said Reader',
#   'Categories': 'scienc social theori subject histori literatur book general anthropolog polit fiction critic nonfict cultur',
#   'Group': 'Book',
#   'Copurchased': '039474067X 0679730672 0679750541 1400030668 0896086704',
#   'SalesRank': 220379,
#   'TotalReviews': 6,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0871318237': {'Id': '11',
#   'Title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life',
#   'Categories': 'health unknown profession altern technic store bodi subject medic jp holist book medicin specialti general mind',
#   'Group': 'Book',
#   'Copurchased': '0060984341 0553577514 1571742972 0962741817',
#   'SalesRank': 412962,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1590770218': {'Id': '12',
#   'Title': 'Fantastic Food with Splenda : 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories',
#   'Categories': 'health carbohydr low carb spice condit herb fat diet food loss special diabet cook sugar subject book wine nutrit bodi general mind weight ingredi free condiment',
#   'Group': 'Book',
#   'Copurchased': '0871319640',
#   'SalesRank': 24741,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0313230269': {'Id': '13',
#   'Title': 'Clockwork Worlds : Mechanized Environments in SF (Contributions to the Study of Science Fiction and Fantasy)',
#   'Categories': 'scienc theori subject histori literatur fantasi book general critic fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2895088,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1559362022': {'Id': '15',
#   'Title': 'Wake Up and Smell the Coffee',
#   'Categories': 'art unit state bogosian subject perform drama b photographi z book theater general eric literatur author fiction',
#   'Group': 'Book',
#   'Copurchased': '1559360968 1559361247 1559360828 1559361018 0743214552',
#   'SalesRank': 518927,
#   'TotalReviews': 8,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0195110382': {'Id': '16',
#   'Title': 'War at Sea: A Naval History of World War II',
#   'Categories': 'war naval subject histori book world militari ii general',
#   'Group': 'Book',
#   'Copurchased': '1585741485 0140246967 1557504288',
#   'SalesRank': 631564,
#   'TotalReviews': 10,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0849311012': {'Id': '17',
#   'Title': 'Telecommunications Cost Management',
#   'Categories': 'invest com leadership oper econom comput subject book microprocessor hardwar design amazon manag engin general internet busi home offic manufactur store telecommun system industri',
#   'Group': 'Book',
#   'Copurchased': '1580531784 1578200326',
#   'SalesRank': 570183,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '078510870X': {'Id': '19',
#   'Title': 'Ultimate Marvel Team-Up',
#   'Categories': 'scienc comic horror children publish subject literatur mysteri fantasi marvel book novel graphic superhero fiction teen',
#   'Group': 'Book',
#   'Copurchased': '078511078X',
#   'SalesRank': 612475,
#   'TotalReviews': 8,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '3895780812': {'Id': '20',
#   'Title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications',
#   'Categories': 'profession technic comput subject medic intern medicin book specialti radiolog general internet',
#   'Group': 'Book',
#   'Copurchased': '0865778973 0071343547 0721662854 0721681735 0819444251',
#   'SalesRank': 179448,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393049388': {'Id': '23',
#   'Title': 'Strange Fire: A Novel',
#   'Categories': 'thriller subject literatur book general contemporari fiction mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1277867,
#   'TotalReviews': 3,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553525476': {'Id': '24',
#   'Title': 'The Casebook of Sherlock Holmes, Volume 2 (Casebook of Sherlock Holmes)',
#   'Categories': 'detect entertain thriller holm show radio subject z book doyl format arthur broadcast british sherlock general conan tape sir author mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1545277,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0939165252': {'Id': '25',
#   'Title': 'Jailed for Freedom: American Women Win the Vote',
#   'Categories': 'women studi subject histori govern book elect nonfict',
#   'Group': 'Book',
#   'Copurchased': '059500055X 0674106539',
#   'SalesRank': 326756,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1590930509': {'Id': '26',
#   'Title': 'Chicken Little',
#   'Categories': 'stori children subject literatur folk book general fairi tale myth pictur age',
#   'Group': 'Book',
#   'Copurchased': '0439078172 0899192254 0688070450 0899193498 1577683684',
#   'SalesRank': 242571,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0231096704': {'Id': '27',
#   'Title': 'The Columbia Anthology of Gay Literature',
#   'Categories': 'studi scienc social group lesbian subject classic literatur book general gay nonfict fiction special',
#   'Group': 'Book',
#   'Copurchased': '0140172483 0375707409 0520078748',
#   'SalesRank': 1119683,
#   'TotalReviews': 2,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1893732290': {'Id': '28',
#   'Title': "God Knows Marriage Isn't Always Easy: 12 Ways to Add Zest (God Knows)",
#   'Categories': 'live spiritu religion subject faith marriag christian book relationship',
#   'Group': 'Book',
#   'Copurchased': '1893732398 0609805797',
#   'SalesRank': 745886,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781718791': {'Id': '29',
#   'Title': 'Advanced Pediatric Clinical Assessment: Skills and Procedures',
#   'Categories': 'profession neonat diagnosi technic assess subject nurs medic medicin book specialti general pediatr',
#   'Group': 'Book',
#   'Copurchased': '0071360387 0323016774 0781735114 0721680178',
#   'SalesRank': 677416,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471150274': {'Id': '30',
#   'Title': 'Solving Statics Problems with MathCAD',
#   'Categories': 'civil unknown aerospac mechan store subject jp engin advanc book specialti general',
#   'Group': 'Book',
#   'Copurchased': '013061081X 1852331666 0070121893',
#   'SalesRank': 227883,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0895872218': {'Id': '31',
#   'Title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining',
#   'Categories': 'invest travel categori com tourism dine food u cook state subject profess intern book wine amazon lodg south general hospit busi home offic region unit store industri',
#   'Group': 'Book',
#   'Copurchased': '1892514656 0767908090',
#   'SalesRank': 507787,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0761116982': {'Id': '32',
#   'Title': 'Staff Meals from Chanterelle',
#   'Categories': 'profession atlant cook region middl subject histori intern book wine general food u gastronomi',
#   'Group': 'Book',
#   'Copurchased': '0393020436 0767903609 0312290233 0471287857',
#   'SalesRank': 150657,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0439240751': {'Id': '33',
#   'Title': 'Double Jeopardy (T*Witches, 6)',
#   'Categories': 'magic children fiction unknown scienc subject jp book teen seri issu fantasi specialti witch twin horror store literatur adventur mysteri',
#   'Group': 'Book',
#   'Copurchased': '0439240727 0439240719 0439240700 0061062499',
#   'SalesRank': 97166,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0618111212': {'Id': '35',
#   'Title': 'Burnt Toast on Davenport Street',
#   'Categories': 'scienc humor horror dog magic children subject literatur fantasi book general pictur fiction anim age mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 317983,
#   'TotalReviews': 5,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1898630038': {'Id': '36',
#   'Title': 'Uists & Barra (Pevensey Island guides)',
#   'Categories': 'scotland travel great amazon com categori store subject book general europ britain',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1406353,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0787950599': {'Id': '38',
#   'Title': 'Resolving Conflicts At Work : A Complete Guide for Everyone on the Job',
#   'Categories': 'health invest com guid digit success occup resourc comput human subject profess counsel book biographi life amazon manag psycholog primer bodi general internet busi mind home offic secret store organiz personnel cultur industri',
#   'Group': 'Book',
#   'Copurchased': '0874777518 0071364315 014028852X 1402200552 078795019X',
#   'SalesRank': 644042,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312199406': {'Id': '39',
#   'Title': 'Night of Many Dreams : A Novel',
#   'Categories': 'club store subject literatur book specialti general contemporari fiction popular',
#   'Group': 'Book',
#   'Copurchased': '0312267568 0312316089 0312099436 0312144075 0446674346',
#   'SalesRank': 57186,
#   'TotalReviews': 22,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1573221740': {'Id': '40',
#   'Title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other',
#   'Categories': 'design memoir garden renov subject biographi book general famili relationship adult child remodel parent home',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 678019,
#   'TotalReviews': 8,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0130132543': {'Id': '41',
#   'Title': 'Workbook: The Long-Term Care Nursing Assistant',
#   'Categories': 'profession patient technic refer subject nurs medic care hospic medicin book physician',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2014896,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486268780': {'Id': '43',
#   'Title': 'Selected Poems (Dover Thrift Editions)',
#   'Categories': 'th centuri unit state subject classic w poetri z literatur book world walt general author fiction whitman singl',
#   'Group': 'Book',
#   'Copurchased': '0486275507 0486401588 0486272737 0486285537 0486264661',
#   'SalesRank': 260300,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1861007418': {'Id': '45',
#   'Title': 'Beginning ASP.NET Databases using C#',
#   'Categories': 'spiritu religion comput eschatolog subject christian book page activ program c web server general internet tool databas languag theolog',
#   'Group': 'Book',
#   'Copurchased': '1861006098 1861007329 1861007191 1861007868',
#   'SalesRank': 48408,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0826449379': {'Id': '46',
#   'Title': "Alternative Worlds in Fantasy Fiction (Contemporary Classics of Children's Literature)",
#   'Categories': 'scienc guid theori subject read classic fantasi literatur histori book general famili parent critic fiction teen',
#   'Group': 'Book',
#   'Copurchased': '0889652015 0380651939 0141301163 0440418321 0689845332',
#   'SalesRank': 1115213,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590568833': {'Id': '47',
#   'Title': 'How to Kill a Monster (Goosebumps)',
#   'Categories': 'spine children stine fiction scienc chill subject z book obsess monster illustr r fantasi general horror literatur author age l mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 654748,
#   'TotalReviews': 10,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0439420717': {'Id': '48',
#   'Title': 'Scooby-doo Mysteries #24 (Scooby-Doo Mysteries)',
#   'Categories': 'detect spine del jame children doo fiction popular scienc humor chill j subject z book scoobi seri fantasi espionag horror literatur author cultur mysteri',
#   'Group': 'Book',
#   'Copurchased': '0439284899 0439284880 043924238X 0439284864 0439188814',
#   'SalesRank': 529184,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0687054532': {'Id': '51',
#   'Title': 'Out on the Edge: A Wake-Up Call for Church Leaders on the Edge of the Media Reformation',
#   'Categories': 'church spiritu pentecost religion subject histori protestant christian book general clergi ministri',
#   'Group': 'Book',
#   'Copurchased': '0687052130 0687069157 0764422979 0687045479 0687083737',
#   'SalesRank': 505266,
#   'TotalReviews': 7,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0875420532': {'Id': '52',
#   'Title': "Secrets of Gypsy Love Magick (Llewellyn's New Age Series)",
#   'Categories': 'health mytholog spiritu magic religion relationship nonfict scienc subject book social bodi general occult love mind folklor romanc sociolog',
#   'Group': 'Book',
#   'Copurchased': '156718099X 1567180973 1578632617',
#   'SalesRank': 409481,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0944708498': {'Id': '53',
#   'Title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future',
#   'Categories': 'invest financ com amazon financi home store subject person book general plan parent retir famili busi age offic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 566643,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0613100093': {'Id': '54',
#   'Title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)',
#   'Categories': 'social taci seri situat children subject peopl betsi classic literatur book general friendship action place age adventur fiction',
#   'Group': 'Book',
#   'Copurchased': '0064400964 0064401103 0064401111 0064405478 0064405451',
#   'SalesRank': 629348,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486275035': {'Id': '55',
#   'Title': 'Goldilocks and the Three Bears : Full-Color Picture Book (Dover Little Activity Books)',
#   'Categories': 'humor children subject literatur book general age',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1269904,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1550416243': {'Id': '56',
#   'Title': 'Three Bricks Shy of a Load: A Collection of True Stories About Ordinary People Doing Really Dumb Stuff!',
#   'Categories': 'humor entertain subject essay book general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2167012,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0398068917': {'Id': '57',
#   'Title': 'Investigating Computer Crime: A Primer for Security Managers',
#   'Categories': 'amazon com manag comput home digit hacker subject store book general internet project busi cultur offic secur',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1501773,
#   'TotalReviews': 1,
#   'AvgRating': 1.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087842461X': {'Id': '58',
#   'Title': 'Raptors of the Rockies: Biology of the Birds of Prey and Species Accounts of the Raptors of the Rockies',
#   'Categories': 'guid birdwatch unknown state subject jp field book rocki outdoor mountain specialti general refer unit region store bird natur',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1091842,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393971694': {'Id': '60',
#   'Title': 'Renaissance Music: Music in Western Europe, 1400-1600 (Norton Introduction to Music History)',
#   'Categories': 'art textbook entertain appreci human subject store histori music use book specialti general new europ critic',
#   'Group': 'Book',
#   'Copurchased': '0393090906 0195122321 0136081924 039395272X',
#   'SalesRank': 373682,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1550373080': {'Id': '61',
#   'Title': 'Hermanos (Hablemos)',
#   'Categories': 'children nonfict juvenil libro subject peopl book format español spanish life sibl bebe multilingu año place en famili infantil',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 890775,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0026879077': {'Id': '62',
#   'Title': 'Scoring High on the Stanford Achievement Test',
#   'Categories': 'refer children subject educ school book nonfict',
#   'Group': 'Book',
#   'Copurchased': '0026879018 1930288034 1930288018 1576906779 193028800X',
#   'SalesRank': 1157369,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0966723821': {'Id': '63',
#   'Title': 'Historia De Cancer De Una Dietista : Informacion & Inspiracion para la Recuperacion & Curacion Sobreviviente de tres canceres',
#   'Categories': 'health cancer disord condit diet loss special libro memoir diseas subject medic intern biographi book academ medicin format español oncolog altern nutrit bodi general mind biografía profession en topic weight memoria',
#   'Group': 'Book',
#   'Copurchased': '0972252207 0963837281 0471346683 0812930665',
#   'SalesRank': 613909,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0689846088': {'Id': '64',
#   'Title': 'A Charlie Brown Christmas',
#   'Categories': 'holiday children subject peopl festiv book christma general age place pictur fiction',
#   'Group': 'Book',
#   'Copurchased': '068984607X 0689850271 0689848218 0689848226 0689851634',
#   'SalesRank': 423424,
#   'TotalReviews': 6,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0273651870': {'Id': '65',
#   'Title': 'Economics for Business',
#   'Categories': 'invest com amazon store subject book general busi home offic',
#   'Group': 'Book',
#   'Copurchased': '0131000691 053438367X',
#   'SalesRank': 963890,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393037622': {'Id': '66',
#   'Title': 'Blood and Guts: A Short History of Medicine',
#   'Categories': 'scienc topic mathemat subject histori medicin book general special',
#   'Group': 'Book',
#   'Copurchased': '0192802674 0393319806 157912156X',
#   'SalesRank': 408761,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1571515429': {'Id': '67',
#   'Title': 'Picture Me With My Friend Jesus: Girl Version (Picture Me)',
#   'Categories': 'jesus children religion subject christian biographi book age fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 784192,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0810114275': {'Id': '68',
#   'Title': 'Experiencing and the Creation of Meaning: A Philosophical and Psychological Approach to the Subjective (Studies in Phenomenology and Existential Philosophy)',
#   'Categories': 'modern phenomenolog subject nonfict philosophi book general movement epistemolog',
#   'Group': 'Book',
#   'Copurchased': '0553278339 0933029012 157230376X 157224044X 0829409378',
#   'SalesRank': 421103,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415925398': {'Id': '69',
#   'Title': 'Negotiated Empires: Centers and Peripheries in the New World, 1500-1820',
#   'Categories': 'studi historiographi america subject histori book general histor',
#   'Group': 'Book',
#   'Copurchased': '0333963415 069100840X 0521627249',
#   'SalesRank': 454490,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415223954': {'Id': '70',
#   'Title': 'Geographies of Young People: The Morally Contested Spaces of Identity (Critical Geographies)',
#   'Categories': 'studi scienc social children human subject nonfict book general geographi sociolog',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 973410,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '157281196X': {'Id': '72',
#   'Title': 'Power of Flowers: An Archetypal Journey Through Nature',
#   'Categories': 'spiritu entertain card subject game religion tarot book general divin new age',
#   'Group': 'Book',
#   'Copurchased': '1572812575 1879181940 1879181827 1879181894',
#   'SalesRank': 348412,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375803394': {'Id': '73',
#   'Title': 'The Perfect Plan (7th Heaven)',
#   'Categories': 'life seri heaven children religion subject peopl literatur christian book general age famili place seventh cultur popular',
#   'Group': 'Book',
#   'Copurchased': '037580336X 0061066249',
#   'SalesRank': 561551,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0113300174': {'Id': '74',
#   'Title': 'Service Delivery (It Infrastructure Library Series)',
#   'Categories': 'scienc invest com amazon leadership manag refer primer store subject offic biographi book general profil busi home compani',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 27507,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786863919': {'Id': '75',
#   'Title': 'Disney A to Z : The Updated Official Encyclopedia (Disney a to Z)',
#   'Categories': 'art pop encyclopedia garden refer entertain antiqu home subject americana televis book movi collect cultur',
#   'Group': 'Book',
#   'Copurchased': '0786885270',
#   'SalesRank': 161879,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1581150040': {'Id': '76',
#   'Title': "The Writer's Legal Guide (2nd ed)",
#   'Categories': 'patent law profession guid write technic refer trademark authorship publish subject intellectu book properti copyright general practic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1151885,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312982178': {'Id': '77',
#   'Title': 'Water Touching Stone',
#   'Categories': 'thriller subject book general mysteri',
#   'Group': 'Book',
#   'Copurchased': '0312978340 1569472424',
#   'SalesRank': 27012,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0874850037': {'Id': '78',
#   'Title': 'The Ebony Cookbook: A Date With a Dish',
#   'Categories': 'african cook region subject intern book wine general american food u',
#   'Group': 'Book',
#   'Copurchased': '0874850908 0688100120 0060958138 0966187202 0688162193',
#   'SalesRank': 140480,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0811726371': {'Id': '79',
#   'Title': "Today's Military Wife: Meeting the Challenges of Service Life (Today's Military Wife)",
#   'Categories': 'women studi refer subject book general nonfict',
#   'Group': 'Book',
#   'Copurchased': '1403303193 0962622826 1401086276',
#   'SalesRank': 7437,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1884997015': {'Id': '80',
#   'Title': 'In Quest of God: The Saga of an Extraordinary Pilgrimage',
#   'Categories': 'spiritu e memoir eastern religion subject eknath z biographi book general author easwaran',
#   'Group': 'Book',
#   'Copurchased': '1573227153 0517543052',
#   'SalesRank': 533031,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0140430407': {'Id': '82',
#   'Title': 'Puddnhead Wilson : And, Those Extraordinary Twins (The Penguin English Library)',
#   'Categories': 'th centuri twain unit state subject classic literatur z paperback book world general mark author fiction',
#   'Group': 'Book',
#   'Copurchased': '0140186867 0553211439 0451527569 0553211587 0140390308',
#   'SalesRank': 60668,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '059516630X': {'Id': '83',
#   'Title': 'A Candle for Bobby',
#   'Categories': 'subject literatur book general contemporari fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 3272795,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0912500476': {'Id': '85',
#   'Title': 'Amamantar Sencillo y Puro',
#   'Categories': 'categori feed toddler babi subject store video music breastfeed book specialti famili parent',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1246085,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0807205249': {'Id': '86',
#   'Title': 'Junie B. Jones Collection: Books 9-12',
#   'Categories': 'children literatur book general tape format fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1525696,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415157528': {'Id': '87',
#   'Title': 'Colloquial Polish: The Complete Course for Beginners (Colloquial Series (Book Only))',
#   'Categories': 'refer instruct subject foreign languag book general english polish thesaurus dictionari',
#   'Group': 'Book',
#   'Copurchased': '2831571979 0415224373 0781802822 0764110209',
#   'SalesRank': 393166,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '039802278X': {'Id': '88',
#   'Title': 'Normal and Abnormal Development: The Influence of Primitive Reflexes on Motor Development',
#   'Categories': '',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 353149,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0671727737': {'Id': '90',
#   'Title': 'The Eagle Has Landed',
#   'Categories': 'stori spi thriller subject book tale intrigu mysteri',
#   'Group': 'Book',
#   'Copurchased': '0671746693 0425157547 0425138232 042517607X 0425148289',
#   'SalesRank': 841921,
#   'TotalReviews': 46,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1566913810': {'Id': '91',
#   'Title': 'Foghorn Outdoors: New England Hiking 3 Ed: The Complete Guide to More than 380 Hikes',
#   'Categories': 'travel categori amazon com region unit state store subject northeast book new england',
#   'Group': 'Book',
#   'Copurchased': '0897323270 1566914027 0881504548 0762701641',
#   'SalesRank': 333198,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '037575380X': {'Id': '92',
#   'Title': 'Black No More : A Novel (Modern Library (Paperback))',
#   'Categories': 'stori unit state subject classic literatur book world general short contemporari fiction',
#   'Group': 'Book',
#   'Copurchased': '1555530249 0807009199 0393956008 048628512X',
#   'SalesRank': 251469,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0965740056': {'Id': '93',
#   'Title': 'BizPricer¿ Business Valuation Manual w/Software',
#   'Categories': 'invest financ com amazon home small store subject entrepreneurship book general busi corpor offic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1485593,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '039572774X': {'Id': '94',
#   'Title': 'The American Heritage Dictionary of Idioms',
#   'Categories': 'refer idiom subject slang book general english thesaurus dictionari',
#   'Group': 'Book',
#   'Copurchased': '006270107X 0844204625 0590381571 0844257796',
#   'SalesRank': 166549,
#   'TotalReviews': 15,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0887402631': {'Id': '95',
#   'Title': 'The Heavy Flak Guns, 1933-1945: 88Mm, 105Mm, 128Mm, 150Mm, and Ballistic Directional Equipment',
#   'Categories': 'scienc technolog subject histori book',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1369585,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0310485002': {'Id': '96',
#   'Title': 'Becoming a Contagious Christian',
#   'Categories': 'live spiritu religion inspir subject protestant christian book general discipleship',
#   'Group': 'Book',
#   'Copurchased': '0310500818 0310250005 0830822763 1576832201 0830819711',
#   'SalesRank': 215846,
#   'TotalReviews': 21,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '042515517X': {'Id': '97',
#   'Title': 'Year of the Tiger',
#   'Categories': 'stori spi thriller subject literatur book general tale fiction contemporari intrigu mysteri',
#   'Group': 'Book',
#   'Copurchased': '0425161021 0425176312 0671725319 0425184250',
#   'SalesRank': 509767,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0071402306': {'Id': '99',
#   'Title': "An Employee's Guide to Stock Options",
#   'Categories': 'profession invest financ com amazon technic store subject person book general option account busi home offic',
#   'Group': 'Book',
#   'Copurchased': '076455364X 0966889924 0471394815 0595169252',
#   'SalesRank': 228734,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0787958743': {'Id': '100',
#   'Title': 'Guide to Effective Staff Development in Health Care Organizations : A Systems Approach to Successful Training (J-B AHA Press)',
#   'Categories': 'profession econom administr technic subject medic medicin book polici general',
#   'Group': 'Book',
#   'Copurchased': '1886624089 0875847471 0787955965',
#   'SalesRank': 783690,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743509315': {'Id': '101',
#   'Title': 'Separation Of Power',
#   'Categories': 'suspens stori spi thriller subject literatur cd book general tale polit genr fiction format intrigu mysteri',
#   'Group': 'Book',
#   'Copurchased': '0671023209 0671047329 0671023187',
#   'SalesRank': 612868,
#   'TotalReviews': 76,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1858685486': {'Id': '102',
#   'Title': 'Mensa Visual Brainteasers',
#   'Categories': 'logic teaser brain entertain subject game book general puzzl',
#   'Group': 'Book',
#   'Copurchased': '0201135493 0970825307',
#   'SalesRank': 576507,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0151803870': {'Id': '103',
#   'Title': 'Selected Essays',
#   'Categories': 'eliot spiritu e religion subject classic literatur essay z book general author fiction',
#   'Group': 'Book',
#   'Copurchased': '0156177358 0811201570 015121185X 0811201511',
#   'SalesRank': 324548,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0820451576': {'Id': '104',
#   'Title': 'Owning Culture: Authorship, Ownership, and Intellectual Property Law (Popular Culture and Everyday Life, Vol. 1)',
#   'Categories': 'profession law technic subject intellectu book properti general busi',
#   'Group': 'Book',
#   'Copurchased': '0814788076 1573928895',
#   'SalesRank': 592661,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1555919332': {'Id': '105',
#   'Title': 'Learning in Overdrive: Designing Curriculum, Instruction, and Assessment from Standards : A Manual for Teachers',
#   'Categories': 'pedagogi profession financ technic theori assess standard subject educ book general lesson plan nonfict',
#   'Group': 'Book',
#   'Copurchased': '0226820319 0871205122 0684836319 013093058X',
#   'SalesRank': 114176,
#   'TotalReviews': 2,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0821825917': {'Id': '106',
#   'Title': 'Filtrations on the Homology of Algebraic Varieties (Memoirs of the American Mathematical Society, 529)',
#   'Categories': 'scienc mathemat subject book general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1646865,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '038548125X': {'Id': '107',
#   'Title': 'Mothers and Daughters',
#   'Categories': 'scienc social categori art motherhood photo camera subject marriag essay photographi book general famili relationship parent nonfict sociolog',
#   'Group': 'Book',
#   'Copurchased': '156138450X 0762411090 0762411147 0811806197',
#   'SalesRank': 432141,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0838531377': {'Id': '108',
#   'Title': 'General Ophthalmology',
#   'Categories': 'profession ophthalmolog technic otolaryngolog medic subject medicin book specialti surgeri',
#   'Group': 'Book',
#   'Copurchased': '0937404632 0940780518 156053429X 0071375430 0891283463',
#   'SalesRank': 635566,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471346608': {'Id': '109',
#   'Title': 'Baby Basics : A Guide for New Parents',
#   'Categories': 'health women childbirth video person babi toddler subject book infant pregnanc bodi music specialti general develop mind store famili parent',
#   'Group': 'Book',
#   'Copurchased': '0062731041 0316778001 0764565168 0761121323',
#   'SalesRank': 502928,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0684868008': {'Id': '110',
#   'Title': 'Casanova in Bohemia : A Novel',
#   'Categories': 'memoir compos mozart entertain classic literatur subject music z biographi book amadeus peopl genr histor wolfgang fiction',
#   'Group': 'Book',
#   'Copurchased': '031211933X 031213570X 1574231596',
#   'SalesRank': 92775,
#   'TotalReviews': 10,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0736805656': {'Id': '111',
#   'Title': 'The Maine Coon Cat (Learning About Cats)',
#   'Categories': 'children subject nonfict book cat anim pet',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1612259,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1572315938': {'Id': '112',
#   'Title': 'Official Microsoft Image Composer Book',
#   'Categories': 'imag applic design illustr site compos html comput subject web commerc book internet develop general graphic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 682312,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0736625801': {'Id': '113',
#   'Title': 'Jesus: A Life',
#   'Categories': '',
#   'Group': 'Book',
#   'Copurchased': '0393317609 0800614437 0140144994 0060616628',
#   'SalesRank': 2213377,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0809240394': {'Id': '114',
#   'Title': 'Bowl Like a Pro',
#   'Categories': 'sport subject bowl book general individu',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 887935,
#   'TotalReviews': 3,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0533139317': {'Id': '115',
#   'Title': 'Growing Millionaire Kids',
#   'Categories': 'invest com amazon store subject book general busi home offic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1217413,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0820112518': {'Id': '116',
#   'Title': 'The Life of Benjamin West',
#   'Categories': 'art memoir subject photographi artist book z v benjamin biographi west general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 3312631,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0380819546': {'Id': '117',
#   'Title': 'Site Unseen : An Emma Fielding Mystery (Emma Fielding Mysteries)',
#   'Categories': 'women sleuth seri thriller subject book general mysteri',
#   'Group': 'Book',
#   'Copurchased': '0380819554',
#   'SalesRank': 38915,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590464272': {'Id': '118',
#   'Title': 'The Magic School Bus At The Waterworks : (autobus Magico Viaja Por...) (Magic School Bus)',
#   'Categories': 'magic children action ficción juvenil fiction scienc libro subject school z book reader degen format español illustr c bruce earli seri bus año pictur joanna en cole literatur natur infantil author adventur age work',
#   'Group': 'Book',
#   'Copurchased': '0590464299 0590006371 059046342X',
#   'SalesRank': 654728,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0849943221': {'Id': '119',
#   'Title': 'Black Friday (Soul Survivor Series, Bk. 4)',
#   'Categories': 'spiritu stori spi religion subject thriller z paperback book general tale tim lahay author fiction intrigu l mysteri',
#   'Group': 'Book',
#   'Copurchased': '0849943205 0849942993',
#   'SalesRank': 762209,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0140445684': {'Id': '120',
#   'Title': 'Capital : A Critique of Political Economy (Penguin Classics)',
#   'Categories': 'communism social radic subject ideolog thought philosophi book general polit nonfict',
#   'Group': 'Book',
#   'Copurchased': '0451527100 0140445757 0879757051 0553585975 1573921394',
#   'SalesRank': 17693,
#   'TotalReviews': 40,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0688060676': {'Id': '121',
#   'Title': 'Ten Black Dots',
#   'Categories': 'crew basic illustr c concept children babi subject store music z book specialti general age author donald',
#   'Group': 'Book',
#   'Copurchased': '0140554955 0671792474 0440404959 0688147402 0689808925',
#   'SalesRank': 144348,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '059047913X': {'Id': '123',
#   'Title': 'You Can Name 100 Dinosaurs!',
#   'Categories': 'children babi subject nonfict book general dinosaur anim',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 651510,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '076453243X': {'Id': '125',
#   'Title': 'Adobe® InDesign¿ Bible',
#   'Categories': 'design illustr comput html adob subject web publish book internet develop general graphic indesign desktop',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 405530,
#   'TotalReviews': 5,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0395530377': {'Id': '126',
#   'Title': 'Houghton Mifflin Mathematics: Practice Activity Level 7',
#   'Categories': 'math scienc mathemat children technolog subject natur book general work teen',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1804602,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0878301534': {'Id': '127',
#   'Title': 'Ballroom Dancing',
#   'Categories': 'ballroom art refer subject perform photographi danc book general popular',
#   'Group': 'Book',
#   'Copurchased': '0028643453 0943955777 0965442330',
#   'SalesRank': 36535,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312871880': {'Id': '128',
#   'Title': 'Irish Stew!',
#   'Categories': 'women sleuth andrew greeley seri thriller subject literatur literari g z book general author fiction mysteri',
#   'Group': 'Book',
#   'Copurchased': '0812576063 0812590236 0812577701 0812590244 0812550773',
#   'SalesRank': 368790,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1579473024': {'Id': '129',
#   'Title': 'Cpt 2003: Current Procedural Terminology (Cpt / Current Procedural Terminology (Standard Edition))',
#   'Categories': 'scienc profession econom record administr technic manag refer subject histori medic book medicin polici general practic reimburs',
#   'Group': 'Book',
#   'Copurchased': '1579473350 1570662592',
#   'SalesRank': 256979,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0767905288': {'Id': '130',
#   'Title': "The O'Reilly Factor: The Good, the Bad, and the Completely Ridiculous in American Life",
#   'Categories': 'parti subject nonfict polit book general practic u',
#   'Group': 'Book',
#   'Copurchased': '0767908481 0060514558',
#   'SalesRank': 29460,
#   'TotalReviews': 375,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '078795893X': {'Id': '131',
#   'Title': 'The 2R Manager: When to Relate, When to Require, and How to Do Both Effectively',
#   'Categories': 'invest com amazon leadership manag small store subject career entrepreneurship book general busi home offic',
#   'Group': 'Book',
#   'Copurchased': '0743212347 0684834316 0875849369',
#   'SalesRank': 122152,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743504097': {'Id': '132',
#   'Title': 'Iyanla Live! : Back to Basics (Iyanla Live!)',
#   'Categories': 'health spiritu religion inspir person subject iyanla help z book self format psycholog bodi philosophi general tape mind vanzant motiv transform v growth author',
#   'Group': 'Book',
#   'Copurchased': '0743507541 0743504089 0743500393 0743506359 0743507924',
#   'SalesRank': 868001,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0877936528': {'Id': '134',
#   'Title': 'Growing Teen Disciples: Strategies for Really Effective Youth Ministry',
#   'Categories': 'youth spiritu religion subject christian book clergi ministri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1646474,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0609608363': {'Id': '135',
#   'Title': 'Wondrous Contrivances : Technology at the Threshold',
#   'Categories': 'scienc unit state mathemat technolog america subject histori book general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 408802,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0452011604': {'Id': '136',
#   'Title': 'Understanding Islam: An Introduction to the Muslim World, Third Revised and Updated Edition',
#   'Categories': 'spiritu religion subject book general islam',
#   'Group': 'Book',
#   'Copurchased': '081296618X 0140175962 0140445587 0195130766',
#   'SalesRank': 90195,
#   'TotalReviews': 14,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781433525': {'Id': '137',
#   'Title': 'Apples of Gold: A Six-Week Nurturing Program for Women',
#   'Categories': 'women live church spiritu issu inspir subject institut religion christian organ book general clergi',
#   'Group': 'Book',
#   'Copurchased': '0781438098 0781438055 1885904177 0891077197',
#   'SalesRank': 129355,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0824518659': {'Id': '139',
#   'Title': 'The Sacred Impulse',
#   'Categories': 'catholic spiritu environ religion inspir subject natur christian book general outdoor ecolog',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 846457,
#   'TotalReviews': 1,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786710772': {'Id': '140',
#   'Title': 'Power & Greed: A Short History of the World',
#   'Categories': 'unknown store subject histori jp book specialti world general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 788014,
#   'TotalReviews': 5,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1886110867': {'Id': '141',
#   'Title': 'Coach K: Building the Duke Dynasty : Building the Duke Dynasty',
#   'Categories': 'colleg sport univers subject basketbal biographi book general',
#   'Group': 'Book',
#   'Copurchased': '0446530603 0446676780 0822313189',
#   'SalesRank': 401565,
#   'TotalReviews': 10,
#   'AvgRating': 2.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590108859': {'Id': '142',
#   'Title': 'Chemical Chaos (Horrible Science)',
#   'Categories': 'scienc children subject natur chemistri book general age work',
#   'Group': 'Book',
#   'Copurchased': '0439043638 0590138596 0590216872',
#   'SalesRank': 280529,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '080784991X': {'Id': '143',
#   'Title': 'Ghosts from the Coast',
#   'Categories': 'mytholog spiritu religion unexplain nonfict fiction scienc ghost supernatur state subject book reader collect social world general occult horror unit literatur folklor mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1079230,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0195044193': {'Id': '144',
#   'Title': 'The Paradox of Change: American Women in the 20th Century',
#   'Categories': 'women studi th centuri unit state subject america histori book general nonfict',
#   'Group': 'Book',
#   'Copurchased': '0465041930 0394745361 025206318X',
#   'SalesRank': 596032,
#   'TotalReviews': 0,
# ...
#  '0762708085': {'Id': '1348',
#   'Title': 'Fun with the Family in Michigan: Hundreds of Ideas for Day Trips with the Kids',
#   'Categories': 'travel categori amazon com region unit state store subject midwest book specialti general famili michigan',
#   'Group': 'Book',
#   'Copurchased': '1560445181 0814328296 0786853026',
#   'SalesRank': 692681,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786868821': {'Id': '1349',
#   'Title': 'Cad: Confessions of a Toxic Bachelor',
#   'Categories': 'women comic humor profession group memoir entertain subject strip book biographi general academ novel graphic journalist specif',
#   'Group': 'Book',
#   'Copurchased': '0306812274 0375726497',
#   'SalesRank': 247366,
#   'TotalReviews': 44,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0826314384': {'Id': '1351',
#   'Title': 'Tierra Amarilla: Stories of New Mexico : Cuentos De Nuevo Mexico (Paso Por Aqui)',
#   'Categories': 'stori unit state british subject thriller literatur book general world short spanish fiction mysteri',
#   'Group': 'Book',
#   'Copurchased': '0884121054',
#   'SalesRank': 920020,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0811201511': {'Id': '1352',
#   'Title': 'ABC of Reading',
#   'Categories': 'th centuri unit state pound subject poetri literatur z book world general p ezra author fiction singl',
#   'Group': 'Book',
#   'Copurchased': '0811201570 0811213269 0811201562 0811201627 0520024273',
#   'SalesRank': 202498,
#   'TotalReviews': 14,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0893343218': {'Id': '1353',
#   'Title': 'Teachers Guide to Community Organization: Strategies for Parent, Teacher and Community Groups to Improve the Schools',
#   'Categories': 'women pedagogi group memoir subject russia educ histori biographi book general polici specif nonfict',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1898676,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '030680736X': {'Id': '1354',
#   'Title': 'Dr. Seuss & Mr. Geisel: A Biography',
#   'Categories': 'dr art guid memoir children subject literatur biographi book general famili charact author parent seuss popular',
#   'Group': 'Book',
#   'Copurchased': '0876146272 0679883568 0679434488',
#   'SalesRank': 97073,
#   'TotalReviews': 9,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0674008340': {'Id': '1355',
#   'Title': 'Black Rice: The African Origins of Rice Cultivation in the Americas',
#   'Categories': 'african studi social scienc group subject book general american nonfict special sociolog',
#   'Group': 'Book',
#   'Copurchased': '0140092331',
#   'SalesRank': 282005,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0742512967': {'Id': '1356',
#   'Title': "American Heat: Ethical Problems With the United States' Response to Global Warming (Studies in Social, Political, and Legal Philosophy)",
#   'Categories': 'modern public environ u subject govern natur philosophi book general polici polit outdoor conserv nonfict',
#   'Group': 'Book',
#   'Copurchased': '1583224777 0871566222 089608650X 0786884401',
#   'SalesRank': 846687,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1558746609': {'Id': '1357',
#   'Title': "Chicken Soup for the Golfer's Soul: Stories of Insight, Inspiration and Laughter on the Links (Chicken Soup Series)",
#   'Categories': 'health spiritu golf religion inspir canfield jack subject help z book format self c sport bodi general mind cd author',
#   'Group': 'Book',
#   'Copurchased': '1558749829 155874875X 1558744606 1558749659',
#   'SalesRank': 476325,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553214985': {'Id': '1358',
#   'Title': 'A Country Doctor (Bantam Classic)',
#   'Categories': 'subject literatur classic book general fiction',
#   'Group': 'Book',
#   'Copurchased': '0451527577 0395345308 0486408841',
#   'SalesRank': 437457,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '4333014786': {'Id': '1360',
#   'Title': 'Zen Seeds: Reflections of a Female Priest',
#   'Categories': 'spiritu religion subject philosophi book general buddhism nonfict',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 512876,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0399146261': {'Id': '1361',
#   'Title': 'Three Complete Novels: Cold Fire, Hideaway, Key to Midnight',
#   'Categories': 'horror k unit state subject z dean book general author koontz',
#   'Group': 'Book',
#   'Copurchased': '0517064871 0517073692 0970998716',
#   'SalesRank': 157418,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0306809389': {'Id': '1365',
#   'Title': 'The Duel for France, 1944: The Men and Battles That Changed the Fate of Europe',
#   'Categories': 'western franc war germani subject histori book general militari world ii europ',
#   'Group': 'Book',
#   'Copurchased': '0760311668',
#   'SalesRank': 575583,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781724716': {'Id': '1367',
#   'Title': 'Child and Adolescent Clinical Psychopharmacology',
#   'Categories': 'health psycholog bodi subject counsel book medicin specialti general pediatr mind psychopharmacolog',
#   'Group': 'Book',
#   'Copurchased': '0521655420 088048330X 0781724694',
#   'SalesRank': 191671,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0803949677': {'Id': '1368',
#   'Title': 'The Power of Silence: Social and Pragmatic Perspectives (Language and Language Behavior)',
#   'Categories': 'scienc social refer word subject languag communic book general nonfict sociolog',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 467756,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0822525771': {'Id': '1369',
#   'Title': "David's Story: A Book About Surgery (Meeting the Challenge)",
#   'Categories': 'children subject book general age',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1848183,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553214039': {'Id': '1370',
#   'Title': 'The Swiss Family Robinson (Bantam Classics)',
#   'Categories': 'subject classic literatur book general action genr adventur fiction',
#   'Group': 'Book',
#   'Copurchased': '0451527046 0486404277 0812550927 059043053X 0140390839',
#   'SalesRank': 1086094,
#   'TotalReviews': 52,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553298046': {'Id': '1371',
#   'Title': 'Specter of the Past (Star Wars: The Hand of Thrawn, Book One)',
#   'Categories': 'scienc war star seri media subject fantasi book general fiction',
#   'Group': 'Book',
#   'Copurchased': '0553564927 0553560719 0553296124 0553574140',
#   'SalesRank': 18558,
#   'TotalReviews': 221,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471625469': {'Id': '1372',
#   'Title': 'An Introduction to the Theory of Numbers',
#   'Categories': 'scienc profession technic theori mathemat subject book number pure',
#   'Group': 'Book',
#   'Copurchased': '0883856190 0198531710 048668735X 038797329X',
#   'SalesRank': 263175,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312063261': {'Id': '1373',
#   'Title': "Dancing on Tisha B'av",
#   'Categories': 'lesbian subject literatur book gay fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 353629,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '8817125539': {'Id': '1374',
#   'Title': 'An Italian in America',
#   'Categories': 'travel categori com amazon memoir store subject biographi book itali general europ',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 238275,
#   'TotalReviews': 14,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0531164659': {'Id': '1375',
#   'Title': 'High School Hazing: When Rites Become Wrongs (Single Title: Teen)',
#   'Categories': 'health scienc social children bodi subject peopl book general place mind teen',
#   'Group': 'Book',
#   'Copurchased': '025321498X',
#   'SalesRank': 431993,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1576751414': {'Id': '1376',
#   'Title': 'Be Your Own Brand: A Breakthrough Formula for Standing Out from the Crowd',
#   'Categories': 'health invest com leadership market success person appli subject help counsel book biographi advertis self sale life amazon psycholog manag primer bodi general busi mind home offic transform secret store',
#   'Group': 'Book',
#   'Copurchased': '0345423593 0967450659 0967450616 0767904923 0375407723',
#   'SalesRank': 141178,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0619016884': {'Id': '1377',
#   'Title': '70-220: MCSE Guide to Designing Microsoft Windows 2000 Security',
#   'Categories': 'com digit oper secur comput publish subject book project mcse certif microsoft amazon manag technolog general internet central cours busi home offic exam os window store system cultur',
#   'Group': 'Book',
#   'Copurchased': '0619016930 0619016892 078212898X',
#   'SalesRank': 148463,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0740725300': {'Id': '1378',
#   'Title': 'Traveling Light 2003 Block Calendar: Releasing the Burdens You Were Never Intended to Bear; The',
#   'Categories': 'note pop spiritu max lucado card subject religion accessori z book general author format cultur l',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 745630,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375503366': {'Id': '1379',
#   'Title': 'The Requiem Shark : A Novel',
#   'Categories': 'sea subject literatur book adventur general genr histor contemporari fiction',
#   'Group': 'Book',
#   'Copurchased': '0375759395 0805066152',
#   'SalesRank': 816290,
#   'TotalReviews': 23,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0914732218': {'Id': '1380',
#   'Title': 'AGHORA, At the Left Hand of God (Aghora)',
#   'Categories': 'spiritu religion subject book buddhism general occult',
#   'Group': 'Book',
#   'Copurchased': '0914732315 0914732374 0892540486 1883725046 0965620832',
#   'SalesRank': 62274,
#   'TotalReviews': 21,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '9812348174': {'Id': '1381',
#   'Title': 'Insight Compact Guide Ireland (Insight Compact Guides)',
#   'Categories': 'insight guidebook travel ireland guid amazon com categori seri store subject book general europ pocket',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1175363,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0632057718': {'Id': '1382',
#   'Title': "Architects' Data",
#   'Categories': 'profession build technic architectur refer subject type style book general',
#   'Group': 'Book',
#   'Copurchased': '0823072711 0471348163',
#   'SalesRank': 365164,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1876175087': {'Id': '1384',
#   'Title': "Che in Africa: Che Guevara's Congo Diary",
#   'Categories': 'leader spi militari republ memoir democrat subject peopl g z biographi book che academ west guevara histor america histori africa cuba general congo profession caribbean notabl polit indi',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 836852,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1870775724': {'Id': '1388',
#   'Title': 'Creating a Music Website',
#   'Categories': 'design site theori comput entertain midi subject perform web composit commerc music book internet develop general etc mixer',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1046034,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0813521505': {'Id': '1389',
#   'Title': "Irrationality: Why We Don't Think Straight!",
#   'Categories': 'health scienc behavior profession technic psycholog bodi subject counsel book general cognit mind',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 739364,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087840273X': {'Id': '1391',
#   'Title': 'Alif Baa: Introduction to Arabic Letters and Sounds',
#   'Categories': 'refer instruct linguist word subject foreign languag book general arab',
#   'Group': 'Book',
#   'Copurchased': '0878402918 0879500034',
#   'SalesRank': 23006,
#   'TotalReviews': 24,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0395742129': {'Id': '1393',
#   'Title': 'A Turkey for Thanksgiving',
#   'Categories': 'eve bunt illustr holiday children subject festiv peopl b z book general age place author thanksgiv fiction',
#   'Group': 'Book',
#   'Copurchased': '0448425297 0448422867 0679852921 0064432041 0531059057',
#   'SalesRank': 273599,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0452284015': {'Id': '1394',
#   'Title': 'The Darwin Awards II : Unnatural Selection',
#   'Categories': 'humor entertain subject essay book general',
#   'Group': 'Book',
#   'Copurchased': '0385483414 0740710028 0385419287',
#   'SalesRank': 26591,
#   'TotalReviews': 31,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743407083': {'Id': '1395',
#   'Title': 'Grand Avenue',
#   'Categories': 'f joy subject literatur z field book general author contemporari fiction romanc',
#   'Group': 'Book',
#   'Copurchased': '0743407067 0380711532 0451155068 0380711524',
#   'SalesRank': 177689,
#   'TotalReviews': 71,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0944386237': {'Id': '1396',
#   'Title': 'The Bible Interpreted in Dream Symbols',
#   'Categories': 'health spiritu religion unexplain religi knowledg mental subject counsel book controversi studi psycholog bodi general occult mind dream mysteri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1598633,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1573801534': {'Id': '1397',
#   'Title': "Insiders' Guide to Yellowstone and Grand Teton",
#   'Categories': 'travel categori com wyom food guidebook state subject book west park campground amazon lodg seri mountain general yellowston region unit store insid',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 944279,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0520203569': {'Id': '1401',
#   'Title': 'Early Modern Japan',
#   'Categories': 'subject histori asia book japan',
#   'Group': 'Book',
#   'Copurchased': '0520218124 0824818504 0860084906 0816512566 0804801843',
#   'SalesRank': 587569,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1878610473': {'Id': '1403',
#   'Title': 'Working in the Dark: Reflections of a Poet of the Barrio',
#   'Categories': 'art memoir subject literatur biographi book general author',
#   'Group': 'Book',
#   'Copurchased': '0802139086 0811211029 0802139477 0802138144 0811210324',
#   'SalesRank': 484620,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1864500069': {'Id': '1405',
#   'Title': 'Loney Planet Chicago City Map (City Maps Series)',
#   'Categories': 'travel categori amazon chicago com region unit state refer subject store midwest book atlas illinoi map',
#   'Group': 'Book',
#   'Copurchased': '0935039244 0935039546',
#   'SalesRank': 554729,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  ...}

# %% [markdown]
# ## Adding recommendation property

# %%
Copurchase_Graph = networkx.Graph() 
for asin, metadata in Amazon_Books.items():
    Copurchase_Graph.add_node(asin) 
    for a in metadata['Copurchased'].split():
        Copurchase_Graph.add_node(a.strip()) 
        similarity = 0 
        n1 = set((Amazon_Books[asin]['Categories']).split())
        n2 = set((Amazon_Books[a]['Categories']).split()) 
        n1In2 = n1 & n2           
        n1Un2 = n1 | n2
        if(len(n1In2)) > 0:
            similarity = round(len(n1In2) / len(n1Un2), 2) 
            Copurchase_Graph.add_edge(asin, a.strip(), weight = similarity)

# %%
dc = networkx.degree(Copurchase_Graph) 
for asin in networkx.nodes(Copurchase_Graph):
    metadata = Amazon_Books[asin] 
    metadata['DegreeCentrality'] = int(dc[asin]) 
    ego = networkx.ego_graph(Copurchase_Graph, asin, radius = 1) 
    metadata['ClusteringCoeff'] = round(networkx.average_clustering(ego), 2)
    Amazon_Books[asin] = metadata

# %%
Amazon_Books_File = open('amazon-books.txt', 'w', encoding = 'utf-8', errors = 'ignore')

Amazon_Books_File.write("Id\t" + "ASIN\t" + "Title\t" + "Categories\t" + "Group\t" + "Copurchased\t" + "SalesRank\t" + "TotalReviews\t" + "AvgRating\t" "DegreeCentrality\t" + 
                        "ClusteringCoeff\n") 

for asin, metadata in Amazon_Books.items(): # converting the meta-data into txt file
     Amazon_Books_File.write(metadata['Id'] + "\t" + \
                             asin + "\t" +  \
                             metadata['Title'] + "\t" + \
                             metadata['Categories'] + "\t" + \
                             metadata['Group'] + "\t" +  \
                             metadata['Copurchased'] + "\t" + \
                             str(metadata['SalesRank']) + "\t" + \
                             str(metadata['TotalReviews']) + "\t" + 
                             str(metadata['AvgRating']) + "\t" + \
                             str(metadata['DegreeCentrality']) + "\t" + \
                             str(metadata['ClusteringCoeff']) + "\n")

Amazon_Books_File.close()

# %%
# writing the adjacency edge list
Amazon_Books_File = open("amazon-books-copurchase.edgelist", 'wb') 
networkx.write_weighted_edgelist(Copurchase_Graph, Amazon_Books_File) 
Amazon_Books_File.close()

# %% [markdown]
# ## Reading the text file

# %%
Books_File = open('amazon-books.txt', 'r', encoding = 'utf-8', errors = 'ignore')
Books = {}
Books_File.readline()
for line in Books_File:
    cell = line.split("\t") 
    MetaData = {}
    MetaData['Id'] = cell[0].strip() 
    ASIN = cell[1].strip()
    MetaData['Title'] = cell[2].strip() 
    MetaData['Categories'] = cell[3].strip() 
    MetaData['Group'] = cell[4].strip() 
    MetaData['Copurchased'] = cell[5].strip()
    MetaData['SalesRank'] = int(cell[6].strip())
    MetaData['TotalReviews'] = int(cell[7].strip())
    MetaData['AvgRating'] = float(cell[8].strip())
    MetaData['DegreeCentrality'] = int(cell[9].strip())
    MetaData['ClusteringCoeff'] = float(cell[10].strip())
    Books[ASIN] = MetaData 
Books_File.close()

# %%
Books_File = open("amazon-books-copurchase.edgelist", "rb") 
Copurchase_Graph = networkx.read_weighted_edgelist(Books_File) 
Books_File.close()

# %% [markdown]
# ## Giving Book id as input for recommending books

# %%
print("Looking for Recommendations for Customer Purchasing this Book: ")
print("---------------------------------------------------------------")
Purchased_ASIN = '0805047905'
print("ASIN = ", Purchased_ASIN)
print("Title = ", Books[Purchased_ASIN]['Title'])
print("SalesRank = ", Books[Purchased_ASIN]['SalesRank'])
print("TotalReviews = ", Books[Purchased_ASIN]['TotalReviews'])
print("AvgRating = ", Books[Purchased_ASIN]['AvgRating'])
print("DegreeCentrality = ", Books[Purchased_ASIN]['DegreeCentrality'])
print("ClusteringCoeff = ", Books[Purchased_ASIN]['ClusteringCoeff'])
# Out:
# Looking for Recommendations for Customer Purchasing this Book:
# ---------------------------------------------------------------
# ASIN =  0805047905
# Title =  Brown Bear, Brown Bear, What Do You See?
# SalesRank =  171
# TotalReviews =  172
# AvgRating =  5.0
# DegreeCentrality =  213
# ClusteringCoeff =  0.66

# %%
n = Purchased_ASIN
ego = networkx.ego_graph(Copurchase_Graph, n, radius = 1)
Purchased_ASIN_Ego_Graph = networkx.Graph(ego)

# %%
threshold = 0.5 # finding the nodes having similarity measure based on category above the threshold value
Purchased_ASIN_Ego_Trim_Graph = networkx.Graph()
for f, t, e in Purchased_ASIN_Ego_Graph.edges(data = True):
    if e['weight'] >= threshold: 
        Purchased_ASIN_Ego_Trim_Graph.add_edge(f, t)

# %%
Purchased_ASIN_Neighbors = Purchased_ASIN_Ego_Trim_Graph.neighbors(Purchased_ASIN)

# %%
ASIN_Meta = []
for asin in Purchased_ASIN_Neighbors:
    ASIN = asin
    Title = Amazon_Books[ASIN]['Title']
    SalesRank = Amazon_Books[ASIN]['SalesRank']
    TotalReviews = Amazon_Books[ASIN]['TotalReviews']
    AvgRating = Amazon_Books[ASIN]['AvgRating']
    DegreeCentrality = Amazon_Books[ASIN]['DegreeCentrality']
    ASIN_Meta.append((ASIN, Title, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff))

# %% [markdown]
# ## Showing Top 5 Recommendations

# %%
Top5_ByAbgRating_ThenByTotalReviews = sorted(ASIN_Meta, key = lambda x: (x[4], x[3]), reverse = True)[:5]

# %%
print()
print("Top 5 Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book: ")
print("--------------------------------------------------------------------------------------")
print('ASIN\t', 'Title\t', 'SalesRank\t', 'TotalReviews\t', 'AvgRating\t', 'DegreeCentrality\t', 'ClusteringCoeff')
for asin in Top5_ByAbgRating_ThenByTotalReviews:
    print(asin)

print()
# Out:
# Top 5 Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book:
# --------------------------------------------------------------------------------------
# ASIN	 Title	 SalesRank	 TotalReviews	 AvgRating	 DegreeCentrality	 ClusteringCoeff
# ('0152010661', 'Time for Bed', 3122, 87, 5.0, 60, 0.0)
# ('0694006246', 'Big Red Barn Board Book', 4457, 40, 5.0, 27, 0.0)
# ('1581170769', 'What Makes a Rainbow?: Pop-Up', 40821, 29, 5.0, 7, 0.0)
# ('0064435962', 'From Head to Toe', 187777, 22, 5.0, 5, 0.0)
# ('0694013013', 'From Head to Toe Board Book', 6026, 22, 5.0, 47, 0.0)
